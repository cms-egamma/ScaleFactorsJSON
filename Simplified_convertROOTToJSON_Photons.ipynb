# %%
ID_sf=[
    
    {"2017":{
        "Loose":"EGdata/SF-Repository/UL17/Photons/Loose/passingLoose100XV2_lowpTChebychev_addGaus/egammaEffi.txt_EGM2D.root",
        "Medium":"EGdata/SF-Repository/UL17/Photons/Medium/egammaEffi.txt_EGM2D.root",
        "Tight":"EGdata/SF-Repository/UL17/Photons/Tight/egammaEffi.txt_EGM2D.root",
        "wp80":"EGdata/SF-Repository/UL17/Photons/MVA80/passingMVA94XV2wp80/egammaEffi.txt_EGM2D.root",
        "wp90":"EGdata/SF-Repository/UL17/Photons/MVA90/passingMVA94XV2wp90/egammaEffi.txt_EGM2D.root",
    }},
    {"2018":{
        "Loose":"EGdata/SF-Repository/UL18/Photons/Loose/passingLoose100XV2/egammaEffi.txt_EGM2D.root",
        "Medium":"EGdata/SF-Repository/UL18/Photons/Medium/passingMedium100XV2/egammaEffi.txt_EGM2D.root",
        "Tight":"EGdata/SF-Repository/UL18/Photons/Tight/passingTight100XV2/egammaEffi.txt_EGM2D.root",
        "wp80":"EGdata/SF-Repository/UL18/Photons/MVA80/passingMVA94XV2wp80/egammaEffi.txt_EGM2D.root",
        "wp90":"EGdata/SF-Repository/UL18/Photons/MVA90/passingMVA94XV2wp90/egammaEffi.txt_EGM2D.root",
    }},
    {"2016postVFP":{
        "Loose":"EGdata/SF-Repository/UL16/postVFP/Photons/Loose/egammaEffi.txt_EGM2D_Pho_Loose_UL16_postVFP.root",
        "Medium":"EGdata/SF-Repository/UL16/postVFP/Photons/Medium/egammaEffi.txt_EGM2D.root",
        "Tight":"EGdata/SF-Repository/UL16/postVFP/Photons/Tight/egammaEffi.txt_EGM2D_Pho_Tight_UL16_postVFP.root",
        "wp80":"EGdata/SF-Repository/UL16/postVFP/Photons/MVA80/egammaEffi.txt_EGM2D_Pho_MVA80_UL16_postVFP.root",
        "wp90":"EGdata/SF-Repository/UL16/postVFP/Photons/MVA90/egammaEffi.txt_EGM2D_Pho_MVA90_UL16_postVFP.root",
    }},
    {"2016preVFP":{
        "Loose":"EGdata/SF-Repository/UL16/preVFP/Photons/Loose/egammaEffi.txt_EGM2D.root",
        "Medium":"EGdata/SF-Repository/UL16/preVFP/Photons/Medium/egammaEffi.txt_EGM2D.root",
        "Tight":"EGdata/SF-Repository/UL16/preVFP/Photons/Tight/egammaEffi.txt_EGM2D.root",
        "wp80":"EGdata/SF-Repository/UL16/preVFP/Photons/MVA80/egammaEffi.txt_EGM2D.root",
        "wp90":"EGdata/SF-Repository/UL16/preVFP/Photons/MVA90/egammaEffi.txt_EGM2D.root",

    }}
]

# %%
    
CSEV_sf=[
    {"2017":{
    "Loose":"EGdata/SF-Repository/CSEV_SummaryPlot_UL17.root",
    "Medium":"EGdata/SF-Repository/CSEV_SummaryPlot_UL17.root",
    "Tight":"EGdata/SF-Repository/CSEV_SummaryPlot_UL17.root",
    "MVA":"EGdata/SF-Repository/CSEV_SummaryPlot_UL17.root",    
    }},
    {"2018":{
    "Loose":"EGdata/SF-Repository/CSEV_SummaryPlot_UL18.root",
    "Medium":"EGdata/SF-Repository/CSEV_SummaryPlot_UL18.root",
    "Tight":"EGdata/SF-Repository/CSEV_SummaryPlot_UL18.root",
    "MVA":"EGdata/SF-Repository/CSEV_SummaryPlot_UL18.root",    
    }},
    {"2016postVFP":{
    "Loose":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_postVFP.root",
    "Medium":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_postVFP.root",
    "Tight":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_postVFP.root",
    "MVA":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_postVFP.root",    
    }},
    {"2016preVFP":{
    "Loose":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_preVFP.root",
    "Medium":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_preVFP.root",
    "Tight":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_preVFP.root",
    "MVA":"EGdata/SF-Repository/CSEV_SummaryPlot_UL16_preVFP.root",
    }}
]

# %%
PixVeto_sf=[
    {"2017":{
    "Loose":"EGdata/SF-Repository/HasPix_SummaryPlot_UL17.root",
    "Medium":"EGdata/SF-Repository/HasPix_SummaryPlot_UL17.root",
    "Tight":"EGdata/SF-Repository/HasPix_SummaryPlot_UL17.root",
    "MVA":"EGdata/SF-Repository/HasPix_SummaryPlot_UL17.root",    
    }},
    {"2018":{
    "Loose":"EGdata/SF-Repository/HasPix_SummaryPlot_UL18.root",
    "Medium":"EGdata/SF-Repository/HasPix_SummaryPlot_UL18.root",
    "Tight":"EGdata/SF-Repository/HasPix_SummaryPlot_UL18.root",
    "MVA":"EGdata/SF-Repository/HasPix_SummaryPlot_UL18.root",    
    }},
    {"2016postVFP":{
    "Loose":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_postVFP.root",
    "Medium":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_postVFP.root",
    "Tight":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_postVFP.root",
    "MVA":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_postVFP.root",    
    }},
    {"2016preVFP":{
    "Loose":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_preVFP.root",
    "Medium":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_preVFP.root",
    "Tight":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_preVFP.root",
    "MVA":"EGdata/SF-Repository/HasPix_SummaryPlot_UL16_preVFP.root",    
    }}
]

# %%
from correctionlib.schemav2 import CorrectionSet
import gzip
from JSONTools import *
# Out:
# Welcome to JupyROOT 6.24/00

# %%
from Class_MakePhotonJSONs import *

years=["2017","2018","2016postVFP","2016preVFP"]
nameJSON="photon.json"
era='UL'

MakePhotonJSONs=MakePhotonJSONs(years)

MakePhotonJSONs.ID(ID_sf)

MakePhotonJSONs.CSEV(CSEV_sf)

MakePhotonJSONs.PixVeto(PixVeto_sf)
# Out:
# Initialized
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 100.0, 200.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 80.0, 120.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 80.0, 120.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 100.0, 200.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 100.0, 200.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 100.0, 200.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 80.0, 120.0, inf]
# X: [-inf, -2.0, -1.566, -1.444, -0.8, 0.0, 0.8, 1.444, 1.566, 2.0, inf]
# Y: [20.0, 35.0, 50.0, 80.0, 120.0, inf]
# ...

# %%
desc="These are the photon ID, Pixel veto and CSEV Scale Factors (nominal, up or down) for {year} Ultra Legacy dataset. Each kind of scale factors, depend on the chosen working point, some other quantities. More information is below! Please keep in the mind that if your analysis is sensitive to high pT photons (>500 GeV), please refer https://twiki.cern.ch/twiki/bin/view/CMS/EGMPhotonIDHighPtPhotons"
        
MakePhotonJSONs.SaveJSONs(desc,years,era,nameJSON)

# %%
##### Checking if everything works

from correctionlib import _core
#Download the correct JSON files 
evaluator = _core.CorrectionSet.from_file('2016postVFP_UL/photon.json')

# %%
valsf= evaluator["Photon-CSEV-SF"].evaluate("2016postVFP","sf","Loose","EBInc")
print("sf is:"+str(valsf))

valsf= evaluator["Photon-PixVeto-SF"].evaluate("2016postVFP","sf","Loose","EBInc")
print("sf is:"+str(valsf))

valsf= evaluator["Photon-PixVeto-SF"].evaluate("2016postVFP","sfup","Loose","EBInc")
print("sfup is:"+str(valsf))

valsf= evaluator["Photon-PixVeto-SF"].evaluate("2016postVFP","sfdown","Loose","EBInc")
print("sfdown is:"+str(valsf))
# Out:
# sf is:0.994726300239563
# sf is:0.9796813130378724
# sfup is:0.9813485076883808
# sfdown is:0.978014118387364
